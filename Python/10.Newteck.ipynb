# %%
import sys
sys.path.append('F:\python\pythonm')  # 追加了搜索目录

# %%
import sys,pprint
pprint.pprint(sys.path)
# Out:
# ['',
#  'c:\\users\\o\\appdata\\local\\enthought\\canopy\\user\\scripts\\python27.zip',
#  'C:\\Users\\O\\AppData\\Local\\Enthought\\Canopy\\App\\appdata\\canopy-1.7.2.3327.win-x86_64\\DLLs',
#  'C:\\Users\\O\\AppData\\Local\\Enthought\\Canopy\\App\\appdata\\canopy-1.7.2.3327.win-x86_64\\lib',
#  'C:\\Users\\O\\AppData\\Local\\Enthought\\Canopy\\App\\appdata\\canopy-1.7.2.3327.win-x86_64\\lib\\plat-win',
#  'C:\\Users\\O\\AppData\\Local\\Enthought\\Canopy\\App\\appdata\\canopy-1.7.2.3327.win-x86_64\\lib\\lib-tk',
#  'C:\\Users\\O\\AppData\\Local\\Enthought\\Canopy\\App\\appdata\\canopy-1.7.2.3327.win-x86_64',
#  'c:\\users\\o\\appdata\\local\\enthought\\canopy\\user',
#  'c:\\users\\o\\appdata\\local\\enthought\\canopy\\user\\lib\\site-packages',
#  'c:\\users\\o\\appdata\\local\\enthought\\canopy\\user\\lib\\site-packages\\win32',
#  'c:\\users\\o\\appdata\\local\\enthought\\canopy\\user\\lib\\site-packages\\win32\\lib',
# ...

# %%
# %quickref

# %%
# %magic

# %%
import copy
[n for n in dir(copy) if not n.startswith('_')]
# Out:
# ['Error',
#  'PyStringMap',
#  'copy',
#  'deepcopy',
#  'dispatch_table',
#  'error',
#  'name',
#  't',
#  'weakref']

# %%
import test1

# %%
print test1.PI
# Out:
# 3.141

# %%
from test1 import marks

# %%
marks.mark()
# Out:
# 'Fuck the regulation!'

# %%
marks.mul(1,2)
# Out:
# 5

# %%
copy.__all__
# Out:
# ['Error', 'copy', 'deepcopy']

# %%
help(copy.copy)
# Out:
# Help on function copy in module copy:
#
# copy(x)
#     Shallow copy operation on arbitrary Python objects.
#
#     See the module's __doc__ string for more info.

# %%
print copy.copy.__doc__
# Out:
# Shallow copy operation on arbitrary Python objects.
#
#     See the module's __doc__ string for more info.

# %%
print copy.deepcopy.__doc__
# Out:
# Deep copy operation on arbitrary Python objects.
#
#     See the module's __doc__ string for more info.

# %%
print range.__doc__
# Out:
# range(stop) -> list of integers
# range(start, stop[, step]) -> list of integers
#
# Return a list containing an arithmetic progression of integers.
# range(i, j) returns [i, i+1, i+2, ..., j-1]; start (!) defaults to 0.
# When step is given, it specifies the increment (or decrement).
# For example, range(4) returns [0, 1, 2, 3].  The end point is omitted!
# These are exactly the valid indices for a list of 4 elements.

# %%
print copy.__file__
# Out:
# C:\Users\O\AppData\Local\Enthought\Canopy\App\appdata\canopy-1.7.2.3327.win-x86_64\lib\copy.pyc

# %%
import time
time.asctime()
# Out:
# 'Tue May 31 13:15:31 2016'

# %%
import random
print random.random()
# Out:
# 0.106847262112

# %%
help(random)
# Out:
# Help on module random:
#
# NAME
#     random - Random variable generators.
#
# FILE
#     c:\users\o\appdata\local\enthought\canopy\app\appdata\canopy-1.7.2.3327.win-x86_64\lib\random.py
#
# DESCRIPTION
#         integers
#         --------
#                uniform within range
#
#         sequences
#         ---------
#                pick random element
#                pick random sample
#                generate random permutation
#
#         distributions on the real line:
#         ------------------------------
#                uniform
#                triangular
#                normal (Gaussian)
#                lognormal
#                negative exponential
#                gamma
#                beta
#                pareto
#                Weibull
#
#         distributions on the circle (angles 0 to 2pi)
#         ---------------------------------------------
#                circular uniform
#                von Mises
#
# ...
